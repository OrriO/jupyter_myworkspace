# %% [markdown]
# ![](./img/chinahadoop.png)

# %% [markdown]
# # 歌曲序列建模
# **[小象学院](http://www.chinahadoop.cn/course/landpage/15)《机器学习集训营》课程资料 by [@寒小阳](http://www.chinahadoop.cn/user/49339/about)**

# %% [markdown]
# 我们来分析一下现在的场景，我们实际需要计算user或者item的相似度，协同过滤等neighborhood的方法是其中的一种。<br>
# 关于相近度这个问题，我们不是第一次遇见，我们在自然语言处理的机器学习问题中，需要把词映射成词向量，最简单的方式是one-hot，而为了达到更好的效果，我们通常需要捕捉一下近义词(比如“宾馆”和“酒店”)，我们会用到一个方法，叫做word2vec。

# %% [markdown]
# ![](./img/word2vec.png)

# %% [markdown]
# ```python
# result = model.most_similar(u"习近平")
# for e in result:
#     print e[0], e[1]
# ```
# ```
# 胡锦涛 0.809472680092
# 江泽民 0.754633367062
# 李克强 0.739740967751
# 贾庆林 0.737033963203
# 曾庆红 0.732847094536
# 吴邦国 0.726941585541
# 总书记 0.719057679176
# 李瑞环 0.716384887695
# 温家宝 0.711952567101
# 王岐山 0.703570842743
# ```

# %% [markdown]
# 说起来word2vec，其实就是把词映射成一定维度的稠密向量，同时保持住词和词之间的关联性，主要体现在(欧式)距离的远近上。
#
# 那么问题来了，word2vec为什么能够学习到这样的结果？
#
# 因为我们相信“物以类聚，人以群分” “一个人的层次与他身边最近的一些人是差不多的”
#
# 同样的考虑，我们是不是可以认为，一个歌单里的歌曲，相互之间都有一定的关联性呢？就像句子中的词一样。答案是，是的！
#
# 咱们来写个程序跑一把。

# %% [markdown]
# ## 从word2vec到song2vec

# %% [markdown]
# 我们把歌曲的id序列取出来，类比于分完词后的句子，送到word2vec中去学习一下，看看会有什么效果。

# %%
#coding: utf-8
import multiprocessing
import gensim
import sys

def parse_playlist_get_sequence(in_line, playlist_sequence):
	song_sequence = []
	contents = in_line.strip().split("\t")
	# 解析歌单序列
	for song in contents[1:]:
		try:
			song_id, song_name, artist, popularity = song.split(":::")
			song_sequence.append(song_id)
		except:
			print "song format error"
			print song+"\n"
	playlist_sequence.append(song_sequence)


def train_song2vec(in_file, out_file):
	#所有歌单序列
	playlist_sequence = []
	#遍历所有歌单
	for line in open(in_file):
		parse_playlist_get_sequence(line, playlist_sequence)
	#使用word2vec训练
	cores = multiprocessing.cpu_count()
	print "using all "+str(cores)+" cores"
	print "Training word2vec model..."
	model = gensim.models.Word2Vec(sentences=playlist_sequence, size=150, min_count=3, window=7, workers=cores)
	print "Saving model..."
	model.save(out_file)

# %%
song_sequence_file = "./163_music_playlist.txt"
model_file = "./song2vec.model"
train_song2vec(song_sequence_file, model_file)
# Out:
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 4967373:::テニスの王子様::ここからが・・・俺達II
#
# song format error
# :::V.A.:::5.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 376653:::野弧禅狂叱(宿香之战)
#
# song format error
# :::霹雳英雄:::5.0
#
# song format error
# 374524:::赎?罪
#
# song format error
# 赎罪岩:::霹雳英雄:::15.0
#
# song format error
# 31563610:::
#
# song format error
# 苍之礼赞:::花之祭P:::65.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 31838468:::Justiφ's(Tv Size Version)
#
# song format error
# :::佐藤和豊:::25.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 405599088:::Make Them Wheels Roll
#
# song format error
# :::SAFIA:::100.0
#
# song format error
# 405599088:::Make Them Wheels Roll
#
# song format error
# :::SAFIA:::100.0
#
# song format error
# 785061:::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝):::沙紗飛鳥:::65.0
#
# song format error
# 33190071:::Theme of Blood Blockade Battlefront
#
# song format error
# :::岩崎太整:::65.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::90.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 405599088:::Make Them Wheels Roll
#
# song format error
# :::SAFIA:::100.0
#
# song format error
# 405599088:::Make Them Wheels Roll
#
# song format error
# :::SAFIA:::100.0
#
# song format error
# 33190071:::Theme of Blood Blockade Battlefront
#
# song format error
# :::岩崎太整:::65.0
#
# song format error
# 33190118:::
#
# song format error
# Dust:::Toft Willingham:::60.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 405599088:::Make Them Wheels Roll
#
# song format error
# :::SAFIA:::100.0
#
# song format error
# 424496188:::大王叫我来巡山 - （原唱：
#
# song format error
#  贾乃亮/贾云馨）:::流浪的蛙蛙:::65.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 427142111:::ウタカタ
#
# song format error
# (原曲: ミストレイク):::Re:Volte:::25.0
#
# song format error
# 405599088:::Make Them Wheels Roll
#
# song format error
# :::SAFIA:::100.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 28684643:::勝利 ~Sengoku3 Mix~ [Bonus Track]
#
# song format error
# :::光栄BGM部:::80.0
#
# song format error
# 28684644:::死亡 ~Sengoku3 Mix~ [Bonus Track]
#
# song format error
# :::光栄BGM部:::80.0
#
# song format error
# 22773056:::ODIN SPHERE’s Theme-Shanachie ver.-【エンディング】
#
# song format error
# :::崎元仁:::15.0
#
# song format error
# 405599088:::Make Them Wheels Roll
#
# song format error
# :::SAFIA:::100.0
#
# song format error
# 33497915:::
#
# song format error
# Frédéric Chopin: Ballade for piano No. 1 in G minor, Op. 23, CT. 2:::Jorge Bolet:::5.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 405599088:::Make Them Wheels Roll
#
# song format error
# :::SAFIA:::100.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 32272104:::
#
# song format error
# Wonderful Love (Radio Edit):::Money Penny:::80.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 441612015:::不客气
#
# song format error
# :::刘世超:::60.0
#
# song format error
# 441612090:::You're Welcome (Jordan Fisher/Lin-Manuel Miranda Version)
#
# song format error
# :::Lin-Manuel Miranda:::35.0
#
# song format error
# 30474690:::
#
# song format error
# Life Of Sin pt.2:::MitiS:::70.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 26249479:::Let's get “あと1センチ"
#
# song format error
# :::AKB48:::20.0
#
# song format error
# 1342772:::Swan Lake, Op.20 - Act 3 - No.20 Danse hongroise (Czárdás)
#
# song format error
# L'Orchestre de la Suisse Romande:::Ernest Ansermet:::5.0
#
# song format error
# 17742280:::
#
# song format error
# Johann Sebastian Bach: Prelude and Fugue in C sharp (WTK, Book, No.3), BWV 848 - Prelude:::Friedrich Gulda:::25.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 26883741:::Concerto For Piano And Orchestra No.2 In E Major, BWV 1053 :
#
# song format error
# I. [Allegro]:::Glenn Gould:::20.0
#
# song format error
# 26883747:::Concerto For Piano And Orchestra No.3 In D Major, BWV 1054 :
#
# song format error
# II. Adagio E Piano Sempre:::Glenn Gould:::20.0
#
# song format error
# 26883754:::Concerto For Piano And Orchestra No.3 In D Major, BWV 1054 :
#
# song format error
# III. Allegro:::Glenn Gould:::20.0
#
# song format error
# 26883744:::Concerto For Piano And Orchestra No.7 In G Minor, BWV 1058 :
#
# song format error
# I. [Allegro]:::Glenn Gould:::20.0
#
# song format error
# 26883757:::Concerto For Piano And Orchestra No.7 In G Minor, BWV 1058 :
#
# song format error
# III. Allegro Assai:::Glenn Gould:::20.0
#
# song format error
# 604259:::Sonata for Violin and Piano No. 3 in G minor (1917): I. Allegro vivo
#
# song format error
# Midori;Robert McDonald:::五嶋美岛丽:::10.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 26884168:::
#
# song format error
# Age Of Loneliness (Enigmatic Club Mix):::Enigma:::5.0
#
# song format error
# 26884170:::
#
# song format error
# Gravity Of Love (Judgement Day Club Mix):::Enigma:::5.0
#
# song format error
# 26884172:::
#
# song format error
# Light Of Your Smile:::Enigma:::5.0
#
# song format error
# 26884175:::
#
# song format error
# Mea Culpa Part Ii (Original Version):::Enigma:::5.0
#
# song format error
# 26884180:::
#
# song format error
# Principles Of Lust (Omen Mix):::Enigma:::5.0
#
# song format error
# 26884182:::
#
# song format error
# Return To Innocence (380 Midnight):::Enigma:::5.0
#
# song format error
# 26884183:::
#
# song format error
# Return To Innocence (Long):::Enigma:::15.0
#
# song format error
# 26884186:::
#
# song format error
# Sadeness Part 1 (Meditation Mix):::Enigma:::5.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 29011079:::
#
# song format error
# 真的很抱歉:::棒棒堂:::15.0
#
# song format error
# 26878881:::
#
# song format error
# Wolfgang Amadeus Mozart: Serenata notturna in D, K.239 - 2. Menuetto - Trio:::Herbert von Karajan:::5.0
#
# song format error
# 29011079:::
#
# song format error
# 真的很抱歉:::棒棒堂:::15.0
#
# song format error
# 604259:::Sonata for Violin and Piano No. 3 in G minor (1917): I. Allegro vivo
#
# song format error
# Midori;Robert McDonald:::五嶋美岛丽:::10.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 28059284:::Earth: The Oldest Computer (The Last Night) (feat. Macklemore)
#
# song format error
# :::Childish Gambino:::20.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 27533077:::夢を抱いて~はじまりのクリスロード~ (instrumental)
#
# song format error
#  - instrumental:::Rake:::35.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 22773056:::ODIN SPHERE’s Theme-Shanachie ver.-【エンディング】
#
# song format error
# :::崎元仁:::15.0
#
# song format error
# 32408314:::
#
# song format error
# Kishinjou set 03 ~ 運河を行き交う人妖:::凛:::20.0
#
# song format error
# 32408315:::
#
# song format error
# Kishinjou set 04 ~ 柳の下のデュラハン:::凛:::15.0
#
# song format error
# 32408321:::
#
# song format error
# Kishinjou set 09 ~ 空中に沈む輝針城:::凛:::5.0
#
# song format error
# 32408322:::
#
# song format error
# Kishinjou set 10 ~ リバースイデオロギー:::凛:::20.0
#
# song format error
# 32408323:::
#
# song format error
# Kishinjou set 11 ~ 針小棒大の天守閣:::凛:::15.0
#
# song format error
# 32408324:::
#
# song format error
# Kishinjou set 12 ~ 輝く針の小人族:::凛:::20.0
#
# song format error
# 32408328:::
#
# song format error
# Kishinjou set 16 ~ 不思議な不思議な道具達:::凛:::5.0
#
# song format error
# 32408334:::
#
# song format error
# Amanojaku set 00 ~ 反則の狼煙を上げろ:::凛:::5.0
#
# song format error
# 32408335:::
#
# song format error
# Amanojaku set 01 ~ 不可能弾幕には反則を:::凛:::15.0
#
# song format error
# 32408338:::
#
# song format error
# Amanojaku set 03 ~ ロマンチック逃飛行:::凛:::15.0
#
# song format error
# 32408339:::
#
# song format error
# Amanojaku set 04 ~ 永遠の三日天下:::凛:::15.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 785061:::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝):::沙紗飛鳥:::60.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 26878881:::
#
# song format error
# Wolfgang Amadeus Mozart: Serenata notturna in D, K.239 - 2. Menuetto - Trio:::Herbert von Karajan:::15.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 785061:::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝):::沙紗飛鳥:::65.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 27582794:::
#
# song format error
# 丑三つ時の里:::黄昏フロンティア:::25.0
#
# song format error
# 686282:::Chapter1 MainBGM
#
# song format error
# PSP ver:::ARTERY VEIN:::55.0
#
# song format error
# 27582794:::
#
# song format error
# 丑三つ時の里:::黄昏フロンティア:::25.0
#
# song format error
# 543634:::江南の大国・呉の参戦
#
# song format error
# :::横山菁児:::60.0
#
# song format error
# 28059284:::Earth: The Oldest Computer (The Last Night) (feat. Macklemore)
#
# song format error
# :::Childish Gambino:::20.0
#
# song format error
# 686282:::Chapter1 MainBGM
#
# song format error
# PSP ver:::ARTERY VEIN:::55.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 5157818:::Divertimento in D, K.334 - 3. Menuetto - Trio -
#
# song format error
# Menuetto:::Wiener MozartEnsemble:::20.0
#
# song format error
# 29005604:::
#
# song format error
# Sehnsucht nach dem Frühling ("Komm, lieber Mai"), song for voice & pian:::Sky:::85.0
#
# song format error
# 686282:::Chapter1 MainBGM
#
# song format error
# PSP ver:::ARTERY VEIN:::55.0
#
# song format error
# 31704021:::
#
# song format error
# Te Iria A Buscar:::DatPhoria:::15.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 31563610:::
#
# song format error
# 苍之礼赞:::花之祭P:::60.0
#
# song format error
# 31654791:::
#
# song format error
# European Intrigue:::Tim Wynn:::45.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 4470537:::Би дуртай
#
# song format error
# Ts.Khulan
#
# song format error
# D.Otgonbaatar
#
# song format error
# Bi durtai:::Hurd:::55.0
#
# song format error
# 4470518:::Яг л чам шиг
#
# song format error
# Sükhzorig
#
# song format error
# D.Otgonbayar
#
# song format error
# Yag l cham shig:::Hurd:::40.0
#
# song format error
# 4470529:::Намуухан орчлон
#
# song format error
# T.Erdenetsogt
#
# song format error
# D.Otgonbayar
#
# song format error
# Namuukhan orchlon:::Hurd:::65.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 28576609:::
#
# song format error
# ロビンとフランキーとブルック ~軍隊蟻たちの狙い~:::浜口史郎:::20.0
#
# song format error
# 28576630:::
#
# song format error
# ベイビーダンス ~ダンスは求愛の印?~:::田中公平:::20.0
#
# song format error
# 28576624:::
#
# song format error
# 先制攻撃 ~鼓動のボリュームを上げろ!~ :::浜口史郎:::25.0
#
# song format error
# 28576631:::
#
# song format error
# シキ ナミをあきらめる ~ルフィ登場~:::浜口史郎:::20.0
#
# song format error
# 28576623:::
#
# song format error
# 最後の戦い ~渾身の巨人の雷斧(ギガント・トールアックス)~:::浜口史郎:::50.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 687792:::Eternal Rite (Switch Remix)
#
# song format error
# (幽雅に咲かせ、墨染の桜　~ Border of Life/东方妖々梦より):::Alstroemeria Records:::10.0
#
# song format error
# 27582794:::
#
# song format error
# 丑三つ時の里:::黄昏フロンティア:::25.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 1512368:::listen
#
# song format error
# 11. Concerto in F minor for Violin, String Orchestra and Continuo, Op. 8, No. 4, RV 297,L'inverno(Winter): II. Largo:::Joshua Bell:::20.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 33497925:::
#
# song format error
# Frédéric Chopin: Etude for piano No. 23 in A minor, Op. 25/11, CT. 36:::Jorge Bolet:::70.0
#
# song format error
# 28482246:::トップをねらえ!予告編集(完全版)0話
#
# song format error
# :::田中公平:::50.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 5157818:::Divertimento in D, K.334 - 3. Menuetto - Trio -
#
# song format error
# Menuetto:::Wiener MozartEnsemble:::20.0
#
# song format error
# 29005604:::
#
# song format error
# Sehnsucht nach dem Frühling ("Komm, lieber Mai"), song for voice & pian:::Sky:::85.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 4470537:::Би дуртай
#
# song format error
# Ts.Khulan
#
# song format error
# D.Otgonbaatar
#
# song format error
# Bi durtai:::Hurd:::55.0
#
# song format error
# 29005604:::
#
# song format error
# Sehnsucht nach dem Frühling ("Komm, lieber Mai"), song for voice & pian:::Sky:::85.0
#
# song format error
# 28122491:::Samhradh Samhradh
#
# song format error
# :::The Gloaming:::5.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 785061:::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝):::沙紗飛鳥:::60.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 1512377:::listen
#
# song format error
# 13. Sonata in G minor for Violin and Basso Continuo,Devil's Trill Sonata:::Joshua Bell:::5.0
#
# song format error
# 25731912:::SONATA No.1 en Si b Mayor, RV.47 Largo Allegro
#
# song format error
#  :::Paul Tortelier:::70.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 17742280:::
#
# song format error
# Johann Sebastian Bach: Prelude and Fugue in C sharp (WTK, Book, No.3), BWV 848 - Prelude:::Friedrich Gulda:::25.0
#
# song format error
# 31654791:::
#
# song format error
# European Intrigue:::Tim Wynn:::45.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 686282:::Chapter1 MainBGM
#
# song format error
# PSP ver:::ARTERY VEIN:::55.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 401386160:::
#
# song format error
#  when you think about her and your brain says no don't do that:::In Love With A Ghost:::55.0
#
# song format error
# 5090113:::Praia Brava歌手
#
# song format error
# Miraflores:::Various Artists:::10.0
#
# song format error
# 725347:::fortissimo-the ultimate crisis- (instrumental)
#
# song format error
# :::fripSide:::50.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 427373827:::Champions (From "Hands of Stone")
#
# song format error
# :::Usher:::30.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 461124237:::
#
# song format error
# ECHO (LET GO) (Max Styler Extended Remix):::Breathe Carolina:::20.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 17742280:::
#
# song format error
# Johann Sebastian Bach: Prelude and Fugue in C sharp (WTK, Book, No.3), BWV 848 - Prelude:::Friedrich Gulda:::25.0
#
# song format error
# 1375664:::Suite No. 3 In G Minor, BWV 808 IV. Sarabande - Les Agréments De La Même Sarabande
#
# song format error
# :::Glenn Gould:::20.0
#
# song format error
# 31477705:::
#
# song format error
# Johann Sebastian Bach: Goldberg Variations, BWV 988 - Variation 9 Canone alla Terza:::Elena Barshai:::20.0
#
# song format error
# 31477724:::
#
# song format error
# Johann Sebastian Bach: Goldberg Variations, BWV 988 - Variation 27 Canone alla Nona:::Elena Barshai:::15.0
#
# song format error
# 33190071:::Theme of Blood Blockade Battlefront
#
# song format error
# :::岩崎太整:::65.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 27704949:::
#
# song format error
# 투명인간 (feat. 있다) (prod. The Quiett):::Fana:::5.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 32408897:::
#
# song format error
# 星空から来た少女:::Elements Garden:::20.0
#
# song format error
# 3696073:::George Murphy
#
# song format error
# Track:::Tom Lehrer:::5.0
#
# song format error
# 4964484:::
#
# song format error
# 魔物退治に、お力を貸して頂けますか:::松来未佑:::60.0
#
# song format error
# 4964487:::頑張ってください。これ、お守りです
#
# song format error
# :::松来未佑:::60.0
#
# song format error
# 4964470:::ウェルカム。あの、ようこそ練馬へ
#
# song format error
# :::松来未佑:::20.0
#
# song format error
# 427142111:::ウタカタ
#
# song format error
# (原曲: ミストレイク):::Re:Volte:::25.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 27591065:::Sonate für Klavier h-moll S 178 - Lento
#
# song format error
# :::Alfred Brendel:::15.0
#
# song format error
# 404184640:::사랑해요(I Love You)
#
# song format error
# (inst.):::金泰妍:::65.0
#
# song format error
# 30474690:::
#
# song format error
# Life Of Sin pt.2:::MitiS:::70.0
#
# song format error
# 31704017:::
#
# song format error
# Everything I Need:::DatPhoria:::20.0
#
# song format error
# 26878881:::
#
# song format error
# Wolfgang Amadeus Mozart: Serenata notturna in D, K.239 - 2. Menuetto - Trio:::Herbert von Karajan:::15.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 3049811:::O Meu Amo/Participacão de Alcione
#
# song format error
# :::Maria Bethânia:::5.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 28797112:::あるがまま
#
# song format error
# :::アナム&マキ:::25.0
#
# song format error
# 686282:::Chapter1 MainBGM
#
# song format error
# PSP ver:::ARTERY VEIN:::55.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 31563610:::
#
# song format error
# 苍之礼赞:::花之祭P:::60.0
#
# song format error
# 31654811:::
#
# song format error
# American Cowboys:::Tim Wynn:::65.0
#
# song format error
# 29005604:::
#
# song format error
# Sehnsucht nach dem Frühling ("Komm, lieber Mai"), song for voice & pian:::Sky:::85.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 26158540:::
#
# song format error
# 窓辺にもたれる少女 アコースティックギター ver. - unplug:::菊地創:::40.0
#
# song format error
# 33241159:::The End (Culture Code Remix)
#
# song format error
# :::Aruna:::20.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 4470529:::Намуухан орчлон
#
# song format error
# T.Erdenetsogt
#
# song format error
# D.Otgonbayar
#
# song format error
# Namuukhan orchlon:::Hurd:::65.0
#
# song format error
# 4470555:::Зүйрлэх аргагүй
#
# song format error
# Kh.Chilaajav
#
# song format error
# D.Otgonbayar
#
# song format error
# Züirlekh argagüi:::Hurd:::25.0
#
# song format error
# 4470524:::Алт
#
# song format error
# B.Oidov
#
# song format error
# D.Otgonbaatar
#
# song format error
# Alt:::Hurd:::20.0
#
# song format error
# 4470542:::Цоглог оюутан
#
# song format error
# B.Oidov
#
# song format error
# D.Otgonbayar
#
# song format error
# Tsoglog oyutan:::Hurd:::25.0
#
# song format error
# 4470526:::Зөрөөд өнгөрсөн бүсгүй
#
# song format error
#
#
# song format error
# D.Otgonbayar
#
# song format error
# Zörööd öngörsön büsgüi:::Hurd:::25.0
#
# song format error
# 4470515:::Энд нэг л биш ээ
#
# song format error
# B.Oidov
#
# song format error
# D.Otgonbayar
#
# song format error
# End neg l bish ee:::Hurd:::25.0
#
# song format error
# 4470533:::Ер бусын сүм
#
# song format error
# T.Erdenetsogt
#
# song format error
# D.Otgonbaatar
#
# song format error
# Yer busyn süm:::Hurd:::20.0
#
# song format error
# 4470559:::Нүүдлийн кино театр
#
# song format error
# B.Oidov
#
# song format error
# D.Otgonbayar
#
# song format error
# Nüüdliin kino teatr:::Hurd:::25.0
#
# song format error
# 4470521:::Зэвүүн харц
#
# song format error
# B.Oidov, P.Kherlen
#
# song format error
# D.Otgonbaatar
#
# song format error
# Zevüün kharts:::Hurd:::20.0
#
# song format error
# 4470551:::Тоотой санагдах юм
#
# song format error
# Kh.Purev
#
# song format error
# S.Ishkhüü
#
# song format error
# Tootoi sanagdakh yum:::Hurd:::25.0
#
# song format error
# 4470547:::Би амьдарч чадна
#
# song format error
# B.Oidov
#
# song format error
# D.Otgonbayar
#
# song format error
# Bi am'darch chadna:::Hurd:::20.0
#
# song format error
# 4470518:::Яг л чам шиг
#
# song format error
# Sükhzorig
#
# song format error
# D.Otgonbayar
#
# song format error
# Yag l cham shig:::Hurd:::40.0
#
# song format error
# 4470571:::Хөгшин атаман
#
# song format error
# B.Oidov
#
# song format error
# D.Otgonbaatar
#
# song format error
# Khögshin ataman:::Hurd:::20.0
#
# song format error
# 4470537:::Би дуртай
#
# song format error
# Ts.Khulan
#
# song format error
# D.Otgonbaatar
#
# song format error
# Bi durtai:::Hurd:::55.0
#
# song format error
# 4470565:::Хонгор сэтгэл
#
# song format error
# B.Bayandalai
#
# song format error
# D.Otgonbayar
#
# song format error
# Khongor setgel:::Hurd:::30.0
#
# song format error
# 461231833:::Yiruma: River Flows In You
#
# song format error
# :::黄旭洋:::40.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 31311586:::Cameltoe(Original Mix)
#
# song format error
# :::Rolvario:::15.0
#
# song format error
# 401386160:::
#
# song format error
#  when you think about her and your brain says no don't do that:::In Love With A Ghost:::55.0
#
# song format error
# 785061:::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝):::沙紗飛鳥:::65.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 30474690:::
#
# song format error
# Life Of Sin pt.2:::MitiS:::70.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 785061:::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝):::沙紗飛鳥:::65.0
#
# song format error
# 33241159:::The End (Culture Code Remix)
#
# song format error
# :::Aruna:::20.0
#
# song format error
# 686282:::Chapter1 MainBGM
#
# song format error
# PSP ver:::ARTERY VEIN:::55.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 30474690:::
#
# song format error
# Life Of Sin pt.2:::MitiS:::70.0
#
# song format error
# 31563610:::
#
# song format error
# 苍之礼赞:::花之祭P:::60.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 27591798:::THIS ILLUSION (inst. 2012 remaster)
#
# song format error
#  - instrumental:::深澤秀行:::20.0
#
# song format error
# 22673328:::HaruHaru -Japanese Version- (Bonus Track)
#
# song format error
# :::BIGBANG:::80.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 30474690:::
#
# song format error
# Life Of Sin pt.2:::MitiS:::70.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 654309:::1. ヴァイオリン协奏曲 ホ短调 作品64 第1楽章:Allegro molto appassionato
#
# song format error
# 试聴する:::诹访内晶子:::15.0
#
# song format error
# 654316:::2. ヴァイオリン协奏曲 ホ短调 作品64 第2楽章:Andante
#
# song format error
# 试聴する:::诹访内晶子:::10.0
#
# song format error
# 654321:::3. ヴァイオリン协奏曲 ホ短调 作品64 第3楽章:Allegretto non troppo-Allegro molto vivace
#
# song format error
# 试聴する:::诹访内晶子:::10.0
#
# song format error
# 654327:::4. ヴァイオリン协奏曲 ニ长调 作品35 第1楽章:Allegro moderato
#
# song format error
# 试聴する:::诹访内晶子:::10.0
#
# song format error
# 654333:::5. ヴァイオリン协奏曲 ニ长调 作品35 第2楽章:Canzonetta:Andante
#
# song format error
# 试聴する:::诹访内晶子:::10.0
#
# song format error
# 654338:::6. ヴァイオリン协奏曲 ニ长调 作品35 第3楽章:Finale:Allegro vivacissimo
#
# song format error
# 试聴する:::诹访内晶子:::10.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 31563610:::
#
# song format error
# 苍之礼赞:::花之祭P:::60.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 30474690:::
#
# song format error
# Life Of Sin pt.2:::MitiS:::70.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 543634:::江南の大国・呉の参戦
#
# song format error
# :::横山菁児:::60.0
#
# song format error
# 785061:::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝):::沙紗飛鳥:::60.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 543634:::江南の大国・呉の参戦
#
# song format error
# :::横山菁児:::60.0
#
# song format error
# 28935319:::
#
# song format error
# สั่น (Album Version):::Boy Sompob:::100.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 4470526:::Зөрөөд өнгөрсөн бүсгүй
#
# song format error
#
#
# song format error
# D.Otgonbayar
#
# song format error
# Zörööd öngörsön büsgüi:::Hurd:::25.0
#
# song format error
# 4470565:::Хонгор сэтгэл
#
# song format error
# B.Bayandalai
#
# song format error
# D.Otgonbayar
#
# song format error
# Khongor setgel:::Hurd:::30.0
#
# song format error
# 4470529:::Намуухан орчлон
#
# song format error
# T.Erdenetsogt
#
# song format error
# D.Otgonbayar
#
# song format error
# Namuukhan orchlon:::Hurd:::65.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 32507377:::
#
# song format error
#  Can You Feel The Love Tonight (ピアノ):::Relax α Wave:::25.0
#
# song format error
# 32507373:::
#
# song format error
#  I See The Light (ピアノ):::Relax α Wave:::25.0
#
# song format error
# 32507372:::
#
# song format error
#  Part Of Your World (ピアノ):::Relax α Wave:::20.0
#
# song format error
# 32507378:::
#
# song format error
#  Someday My Prince Will Come (ピアノ):::Relax α Wave:::20.0
#
# song format error
# 32507375:::
#
# song format error
#  Let It Go (ピアノ):::Relax α Wave:::20.0
#
# song format error
# 32507376:::
#
# song format error
#  Beauty And The Beast (ピアノ):::Relax α Wave:::20.0
#
# song format error
# 32507374:::
#
# song format error
#  LA LA Lu (ピアノ):::Relax α Wave:::20.0
#
# song format error
# 461231833:::Yiruma: River Flows In You
#
# song format error
# :::黄旭洋:::40.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 27137314:::English Suite No.5 In E Minor, BWV 810 Sarabande
#
# song format error
# :::Glenn Gould:::20.0
#
# song format error
# 2924300:::
#
# song format error
#  Les Peulles Mortes (Autum Leaves):::Laura Fygi:::85.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 31563610:::
#
# song format error
# 苍之礼赞:::花之祭P:::60.0
#
# song format error
# 31563610:::
#
# song format error
# 苍之礼赞:::花之祭P:::60.0
#
# song format error
# 31654781:::
#
# song format error
# Grinder 2 :::Frank Klepacki:::50.0
#
# song format error
# 31654791:::
#
# song format error
# European Intrigue:::Tim Wynn:::45.0
#
# song format error
# 31654806:::
#
# song format error
# Mecha Storm:::James Hannigan:::80.0
#
# song format error
# 31654811:::
#
# song format error
# American Cowboys:::Tim Wynn:::70.0
#
# song format error
# 31654818:::
#
# song format error
# Radio Sunrise:::James Hannigan:::25.0
#
# song format error
# 31654822:::
#
# song format error
# He's Escaping!:::James Hannigan:::25.0
#
# song format error
# 31654824:::
#
# song format error
# Into the Volcano :::Tim Wynn:::25.0
#
# song format error
# 26902203:::What’s your name? (collaboration with 壇蜜)
#
# song format error
# :::SoulJa:::100.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 33085638:::
#
# song format error
# 新婚初夜メッセージ (春日野 紫子):::有栖川みや美:::15.0
#
# song format error
# 31654791:::
#
# song format error
# European Intrigue:::Tim Wynn:::45.0
#
# song format error
# 426291251:::Brand New Moves (Nomekop Remix)
#
# song format error
# :::Hey Violet:::25.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 22642373:::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-:::高梨康治:::95.0
#
# song format error
# 29715639:::The Vow
#
# song format error
# :::Steven Cravis:::25.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 33054290:::
#
# song format error
# Heartbeats:::Dabin:::95.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 28576609:::
#
# song format error
# ロビンとフランキーとブルック ~軍隊蟻たちの狙い~:::浜口史郎:::20.0
#
# song format error
# 28576630:::
#
# song format error
# ベイビーダンス ~ダンスは求愛の印?~:::田中公平:::20.0
#
# song format error
# 28576624:::
#
# song format error
# 先制攻撃 ~鼓動のボリュームを上げろ!~ :::浜口史郎:::25.0
#
# song format error
# 28576631:::
#
# song format error
# シキ ナミをあきらめる ~ルフィ登場~:::浜口史郎:::20.0
#
# song format error
# 28576623:::
#
# song format error
# 最後の戦い ~渾身の巨人の雷斧(ギガント・トールアックス)~:::浜口史郎:::50.0
#
# song format error
# 26884168:::
#
# song format error
# Age Of Loneliness (Enigmatic Club Mix):::Enigma:::5.0
#
# song format error
# 26884170:::
#
# song format error
# Gravity Of Love (Judgement Day Club Mix):::Enigma:::5.0
#
# song format error
# 26884172:::
#
# song format error
# Light Of Your Smile:::Enigma:::5.0
#
# song format error
# 26884175:::
#
# song format error
# Mea Culpa Part Ii (Original Version):::Enigma:::5.0
#
# song format error
# 26884180:::
#
# song format error
# Principles Of Lust (Omen Mix):::Enigma:::5.0
#
# song format error
# 26884182:::
#
# song format error
# Return To Innocence (380 Midnight):::Enigma:::5.0
#
# song format error
# 26884183:::
#
# song format error
# Return To Innocence (Long):::Enigma:::5.0
#
# song format error
# 26884186:::
#
# song format error
# Sadeness Part 1 (Meditation Mix):::Enigma:::5.0
#
# song format error
# 27511866:::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# :::f(x):::95.0
#
# song format error
# 32272105:::
#
# song format error
# Wonderful Love (DJ Raf Remix):::Money Penny:::95.0
#
# song format error
# 32408314:::
#
# song format error
# Kishinjou set 03 ~ 運河を行き交う人妖:::凛:::20.0
#
# song format error
# 32408315:::
#
# song format error
# Kishinjou set 04 ~ 柳の下のデュラハン:::凛:::15.0
#
# song format error
# 32408321:::
#
# song format error
# Kishinjou set 09 ~ 空中に沈む輝針城:::凛:::5.0
#
# song format error
# 32408322:::
#
# song format error
# Kishinjou set 10 ~ リバースイデオロギー:::凛:::20.0
#
# song format error
# 32408323:::
#
# song format error
# Kishinjou set 11 ~ 針小棒大の天守閣:::凛:::15.0
#
# song format error
# 32408324:::
#
# song format error
# Kishinjou set 12 ~ 輝く針の小人族:::凛:::20.0
#
# song format error
# 32408328:::
#
# song format error
# Kishinjou set 16 ~ 不思議な不思議な道具達:::凛:::5.0
#
# song format error
# 32408334:::
#
# song format error
# Amanojaku set 00 ~ 反則の狼煙を上げろ:::凛:::5.0
#
# song format error
# 32408335:::
#
# song format error
# Amanojaku set 01 ~ 不可能弾幕には反則を:::凛:::15.0
#
# song format error
# 32408338:::
#
# song format error
# Amanojaku set 03 ~ ロマンチック逃飛行:::凛:::5.0
#
# song format error
# 32408339:::
#
# song format error
# Amanojaku set 04 ~ 永遠の三日天下:::凛:::15.0
#
# song format error
# 746863:::黒い海に红く
#
# song format error
# (东方绯想天):::はちみつくまさん:::25.0
#
# song format error
# 746854:::无间の钟　~ Infinite Nightmare
#
# song format error
# (东方ダブルスポイラー):::はちみつくまさん:::25.0
#
# song format error
# 31477705:::
#
# song format error
# Johann Sebastian Bach: Goldberg Variations, BWV 988 - Variation 9 Canone alla Terza:::Elena Barshai:::20.0
#
# song format error
# 19169096:::
#
# song format error
#  Time to Say Goodbye (Con te partirò):::Sarah Brightman:::100.0
#
# song format error
# 28576609:::
#
# song format error
# ロビンとフランキーとブルック ~軍隊蟻たちの狙い~:::浜口史郎:::20.0
#
# song format error
# 28576623:::
#
# song format error
# 最後の戦い ~渾身の巨人の雷斧(ギガント・トールアックス)~:::浜口史郎:::50.0
#
# song format error
# 28576624:::
#
# song format error
# 先制攻撃 ~鼓動のボリュームを上げろ!~ :::浜口史郎:::25.0
#
# song format error
# 28576630:::
#
# song format error
# ベイビーダンス ~ダンスは求愛の印?~:::田中公平:::20.0
#
# song format error
# 28576631:::
#
# song format error
# シキ ナミをあきらめる ~ルフィ登場~:::浜口史郎:::20.0
#
# song format error
# 1375664:::Suite No. 3 In G Minor, BWV 808 IV. Sarabande - Les Agréments De La Même Sarabande
#
# song format error
# :::Glenn Gould:::20.0
#
# song format error
# 29722334:::For You
#
# song format error
# :::FiFi Rong:::90.0
#
# song format error
# 27704949:::
#
# song format error
# 투명인간 (feat. 있다) (prod. The Quiett):::Fana:::5.0
#
# song format error
# 27704951:::
#
# song format error
# Code Name : SOUL (prod. Vida Loca):::Fana:::5.0
#
# song format error
# 5157818:::Divertimento in D, K.334 - 3. Menuetto - Trio -
#
# song format error
# Menuetto:::Wiener MozartEnsemble:::20.0
#
# song format error
# 725347:::fortissimo-the ultimate crisis- (instrumental)
#
# song format error
# :::fripSide:::50.0
#
# using all 8 cores
# Training word2vec model...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-f0d3cdaa49e4> in <module>()
#       1 song_sequence_file = "./163_music_playlist.txt"
#       2 model_file = "./song2vec.model"
# ----> 3 train_song2vec(song_sequence_file, model_file)
#
# <ipython-input-1-7f21b6062f18> in train_song2vec(in_file, out_file)
#      30         print "using all "+str(cores)+" cores"
#      31         print "Training word2vec model..."
# ---> 32         model = gensim.models.Word2Vec(sentences=playlist_sequence, size=150, min_count=3, window=7, workers=cores)
#      33         print "Saving model..."
#      34         model.save(out_file)
#
# /Library/Python/2.7/site-packages/gensim/models/word2vec.pyc in __init__(self, sentences, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words)
#     476             if isinstance(sentences, GeneratorType):
#     477                 raise TypeError("You can't pass a generator as the sentences argument. Try an iterator.")
# --> 478             self.build_vocab(sentences, trim_rule=trim_rule)
#     479             self.train(sentences, total_examples=self.corpus_count, epochs=self.iter,
#     480                        start_alpha=self.alpha, end_alpha=self.min_alpha)
#
# /Library/Python/2.7/site-packages/gensim/models/word2vec.pyc in build_vocab(self, sentences, keep_raw_vocab, trim_rule, progress_per, update)
#     551
#     552         """
# --> 553         self.scan_vocab(sentences, progress_per=progress_per, trim_rule=trim_rule)  # initial survey
#     554         self.scale_vocab(keep_raw_vocab=keep_raw_vocab, trim_rule=trim_rule, update=update)  # trim by min_count & precalculate downsampling
#     555         self.finalize_vocab(update=update)  # build tables & arrays
#
# /Library/Python/2.7/site-packages/gensim/models/word2vec.pyc in scan_vocab(self, sentences, progress_per, trim_rule)
#     574                 logger.info("PROGRESS: at sentence #%i, processed %i words, keeping %i word types",
#     575                             sentence_no, sum(itervalues(vocab)) + total_words, len(vocab))
# --> 576             for word in sentence:
#     577                 vocab[word] += 1
#     578
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# 模型已经训练完了，咱们来试一把预测，看看效果
#
# 这个预测的过程，实际上就是对某首歌曲，查找“最近”的歌曲（向量距离最近的歌曲）

# %%
import cPickle as pickle
song_dic = pickle.load(open("song.pkl","rb"))
model_str = "./song2vec.model"
model = gensim.models.Word2Vec.load(model_str)

# %%
song_id_list = song_dic.keys()[1000:1500:50]
for song_id in song_id_list:
    result_song_list = model.most_similar(song_id)

    print song_id, song_dic[song_id]
    print "\n相似歌曲 和 相似度 分别为:"
    for song in result_song_list:
        print "\t", song_dic[song[0]], song[1]
    print "\n"
# Out:
# 29356670 にじいろのはる	ふわりP
#
# 相似歌曲 和 相似度 分别为:
# 	Aglamak Yok	Deniz Seki 0.379099398851
# 	知足（粤语版）（Cover 五月天）	阿细 0.356632173061
# 	Lifestyle	Joe Satriani 0.355613797903
# 	今昔幻想郷	まらしぃ 0.354855984449
# 	T・S・F in にっぽん!(Instrumental)	古川由利奈 0.353581249714
# 	Tokyo Operation	Dark Fount 0.35260361433
# 	爱到你发狂	谭咏麟 0.351889967918
# 	Pilgrimage	Terry Oldfield 0.351281344891
# 	Fortress (Radio Edit)	Ost & Meyer 0.349154919386
# 	Dreaming	Blue Lunar Monkey 0.346552073956
#
#
# 22677823 大阪ラプソディー	中澤裕子
#
# 相似歌曲 和 相似度 分别为:
# 	FRIENDSHIP	girl next door 0.396412461996
# 	아.미.고 (AMIGO: 아름다운 미녀를 좋아하면 고생한다)	SHINee 0.356553256512
# 	Red Omen	Two Steps From Hell 0.353555381298
# 	Consolação	Tenório Júnior E Seu Conjunto 0.347329318523
# 	First Meeting	Lightnin' Hopkins 0.345592081547
# 	めざまし 宁々	V.A. 0.344163119793
# 	Staendchen	Franz Schubert 0.343052297831
# 	Quiet Lake	Terry Oldfield 0.340119510889
# 	Love Is Bubble	BONNIE PINK 0.339400202036
# 	내가 사랑할 사람 (Piano ver.)	李仙姬 0.337993532419
#
#
# 28838650 想いのカナタ Game Size	Famishin
#
# 相似歌曲 和 相似度 分别为:
# 	Everyone Is Sleeping	Little Birdy 0.364472776651
# 	Baila El Chiki Chiki	King Africa 0.360753715038
# 	Pokusa	Alexander Maliszewsi 0.352212429047
# 	I Should Have Known Better	The Beatles 0.35066100955
# 	Hotline Bling (Jason Casper 2016 Remix)	Jason Casper 0.349049270153
# 	Tantra Of Love	Peter Sterling 0.345982462168
# 	Zombie	Maître Gims 0.345564335585
# 	regret	星村麻衣 0.342455267906
# 	相见欢(李煜)	双龙兄弟 0.339726686478
# 	Hello (Bonus Track)	The Chipettes 0.338953495026
#
#
# 26912133 Rapture (Avicii New Generation	Nadia Ali
#
# 相似歌曲 和 相似度 分别为:
# 	苏菲小姐	鱼果 0.407874137163
# 	大切だからfull chorus Ver.	真理絵 0.384827673435
# 	Recovery	Duumu 0.384506613016
# 	Vivaldi: Violin Sonata In A, Op. 2 – 2, RV 31 – 1. Preludio A Capriccio 13.-16.	Various Artists 0.381154626608
# 	鬼迷心窍	李宗盛 0.372498750687
# 	Tribe	Whyt Noyz 0.365835011005
# 	两个女孩的无声对话	新裤子 0.36564874649
# 	Northern Lights	Lisa Lynne 0.363415241241
# 	海上花	小娟&山谷里的居民 0.360533893108
# 	Every Minute	JJ Grey & Mofro 0.352525293827
#
#
# 1873661 Maggie May	Rod Stewart
#
# 相似歌曲 和 相似度 分别为:
# 	东海野外	网易游戏 0.383529156446
# 	Traveling	Future Prophecy 0.378285318613
# 	《魂归》——剑网3天策门派同人原创主题曲	月蝕 0.372299432755
# 	Blood Brothers	Papa Roach 0.372223168612
# 	Melancholy Galliard	Daniel Estrem 0.366955250502
# 	Cold Blooded Killa	VIOLET 0.35383400321
# 	BonusTrack1	うんちく商事 0.349306553602
# 	La Guitarra	Ørjan Nilsen 0.348621785641
# 	Hurricane	Bob Dylan 0.346632957458
# 	Change of Mind	Peter Erskine 0.346551448107
#
#
# 176430 爱上你是一个错	杨培安
#
# 相似歌曲 和 相似度 分别为:
# 	广岛之恋	莫文蔚 0.450452655554
# 	九百九十九朵玫瑰	邰正宵 0.434863299131
# 	一路上有你	张学友 0.43212094903
# 	几分伤心几分痴	王杰 0.427113205194
# 	为爱痴狂	刘若英 0.426759600639
# 	再回首	姜育恒 0.419929265976
# 	一场游戏一场梦	王杰 0.415349900723
# 	雨蝶	李翊君 0.414625644684
# 	中华民谣	孙浩 0.414144873619
# 	千纸鹤	邰正宵 0.413807719946
#
#
# 31477265 Lay Me Down (Tiësto Remix)	Sam Smith
#
# 相似歌曲 和 相似度 分别为:
# 	青丝	群星 0.410337507725
# 	您有一条新留言	日语听力 0.392681121826
# 	This Heaven	Love and Rockets 0.392416268587
# 	 Give Up	FKA twigs 0.382234424353
# 	Tudo Doi	Gal Costa 0.380280703306
# 	If It Feels Good Do It	Sloan 0.374906092882
# 	TITLE	趣味工房にんじんわいん 0.372174650431
# 	Almighty & Everlasting God	Choir Of King's College, Cambridge 0.368153572083
# 	Thank You, Lord, For Sending Me the F Train	Mike Doughty 0.363522917032
# 	취향저격	Kassy 0.353932440281
#
#
# 433103574 Too Much (Remix) feat. 苟乃鹏	艾福杰尼
#
# 相似歌曲 和 相似度 分别为:
# 	人民在我心中	阎维文 0.371013820171
# 	Hawaii	Meiko 0.353350996971
# 	Marche pour la ceremonie des Tures	Jean-Baptiste Lully 0.351304322481
# 	鲜花满月楼	张德兰 0.347662299871
# 	大鱼	乐正绫 0.34764161706
# 	降魔	Lobzang Norbu 0.342688828707
# 	Tchaikovsky: Symphony No.6 in B minor, Op.74 -"Pathétique" - 2. Allegro con grazia	Philharmonia Orchestra 0.339984178543
# 	未来へ	西村由紀江 0.339185923338
# 	Zombie	Breed 77 0.338891625404
# 	我不是歌手	苏醒 0.334780186415
#
#
# 462857501 誕生の時来たれり ~御使いの四柱戦~	芳賀敬太
#
# 相似歌曲 和 相似度 分别为:
# 	よいこのハヤテかるた“う”	白石凉子 0.367800414562
# 	七夕	邓丽欣 0.366510599852
# 	Wave	后海大鲨鱼 0.361391067505
# 	威廉莎士比亚The actors come to town	英语听力 0.360118687153
# 	Manlailan Devegchiin Duu	Hurd 0.359093815088
# 	心灵之乡	弹拨尔 0.347874045372
# 	牧人喜悦	乌云毕力格 0.346149265766
# 	Amazing Grace	Willie Nelson 0.344356507063
# 	Five String Serenade	Mazzy Star 0.340453207493
# 	芦花河	程砚秋 0.335796058178
#
#
# 22787695 さくらガール (NEWS)	NEW ROMAN TRIO
#
# 相似歌曲 和 相似度 分别为:
# 	Searchin'	Verbal Jint 0.376744687557
# 	Deadmen	Rompeprop 0.362828701735
# 	Lie Down In Darkness (Paul van Dyk Remix) - remix	Moby 0.361681312323
# 	Burn It	Nicolas Haelg 0.355559647083
# 	鬼阴山	林坤信 0.35134807229
# 	莞尔	LOFIMAKER 0.34451380372
# 	흔들려	LA.G 0.342868000269
# 	Stereo Love (Digital Dog Club Mix)	Edward Maya 0.342574685812
# 	寂寞的月亮	王俊雄 0.342103004456
# 	Everybody's Kissing In Paris	Anne Bisson 0.341611176729

# %% [markdown]
# ## 进一步思考

# %% [markdown]
# 所以我们用word2vec学会了哪些歌曲和哪些歌曲最接近。
#
# 我们来思考一些很现实同时又很难解决的问题。比如：
# ### 冷启动问题
# 我们经常会遇到冷启动的问题，比如没有任何信息的歌曲，我们如何对它做推荐呢？
# * 如果是歌手发行的新歌曲，我们怎么进行推荐呢？
# * 如果我听完(并收藏)了一首很冷门的歌，怎么进行推荐呢？
#
# 我们知道新歌(或者小众的歌)是非常难和其他的歌关联上的，我们有的信息太少了(很少有用户在它上面发生行为)。
#
# 1.1 一种解决办法当然是推荐热门的歌曲，但是其实没从个人兴趣出发，我们知道这并不是最好的办法，并没有太大的卵用。
#
# 1.2 我们把问题的粒度放粗一点，用同样的思路，比如一个可考虑的解决方案是，我们把**歌曲**的粒度上升到对应的**歌手**，把刚才的song_list替换成artist_list，重新用word2vec建模，这样我们可以得到和一个歌手最相关(接近)的歌手，再推荐这个歌手最热门的歌曲，相对1.1的方法针对性强一些。
#
# ### 用户兴趣预测问题
# 我们刚才完成的功能，类似酷狗音乐和网易音乐里针对一首歌的**“相似音乐”**，那么问题又来了，如果我们现在要对一个user用这套song2vec的方式推荐，我们怎么做呢？
#
# * 每个人的兴趣都是有时效性的，这意味着说，3年前我喜欢王菲的歌，去年我喜欢五月天的歌，而今年我可能就改摇滚路线，喜欢汪峰的歌了。
# * 每一首歌的热度也是不一样的，有一些热门的歌，如果用户能喜欢，当然是首选
#
# 那么，我们来做一个粗暴一点点的处理，把这2个维度拉进来，一起来针对一个用户做推荐。
#
# **把每个用户喜欢(收藏)过的歌，沿着时间轴排好，同时由近到远给不同的衰减因子(比如最近一首歌是1，前一首是0.98，再前一首是0.98^2，以此类推...)，同时我们针对不同的歌曲热度，给定不同的推荐因子(比如热度100的是1，热度80的是0.9...)，每一首歌都可以拿回一个song2vec的推荐列表和对应的相似度，对相似度以时间衰减因子和热度权重进行加权，最后的结果排序后，展示给用户。**
